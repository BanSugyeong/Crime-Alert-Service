# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop_male = pd.read_csv('1인가구_남자.csv', encoding='cp949', index_col=0)
pop_female = pd.read_csv('1인가구_여자.csv', encoding='cp949', index_col=0)
crime = pd.read_csv('년,월별 총 범죄데이터.csv', encoding='cp949', index_col=0)
crime_rate = pd.read_csv('년도별 범죄율 데이터만.csv', encoding='cp949', index_col=0)

# %%
df = pd.concat([pop_male, pop_female, crime, crime_rate], axis=1)
df
# Out:
#       2020_20대_남자  2020_30대_남자  2020_40대_남자  2020_50대_남자  2021_20대_남자  \
# 강남구          5736        10181         5750         3512         5733
# 강동구          3599         6026         4357         4360         4321
# 강북구          3119         3973         3644         4240         3387
# 강서구          7431        12363         6444         5323         8264
# 관악구         24849        20454         8698         6451        25945
# 광진구          8938         7779         4310         4100         9453
# 구로구          4476         6645         4490         4330         4928
# 금천구          4625         6108         3561         4205         5257
# 노원구          5161         4292         3699         3825         5566
# 도봉구          1741         2878         2783         3191         1917
# 동대문구        10168         5918         4000         4078        11006
# 동작구         10444         8266         4031         3075        11117
# ...

# %%
df.columns
# Out:
# Index(['2020_20대_남자', '2020_30대_남자', '2020_40대_남자', '2020_50대_남자',
#        '2021_20대_남자', '2021_30대_남자', '2021_40대_남자', '2021_50대_남자',
#        '2022_20대_남자', '2022_30대_남자', '2022_40대_남자', '2022_50대_남자',
#        '2020_20대_여자', '2020_30대_여자', '2020_40대_여자', '2020_50대_여자',
#        '2021_20대_여자', '2021_30대_여자', '2021_40대_여자', '2021_50대_여자',
#        '2022_20대_여자', '2022_30대_여자', '2022_40대_여자', '2022_50대_여자',
#        '20년1월_범죄건수', '21년1월_범죄건수', '22년1월_범죄건수', '20년2월_범죄건수', '21년2월_범죄건수',
#        '22년2월_범죄건수', '20년3월_범죄건수', '21년3월_범죄건수', '22년3월_범죄건수', '20년4월_범죄건수',
#        '21년4월_범죄건수', '22년4월_범죄건수', '20년5월_범죄건수', '21년5월_범죄건수', '22년5월_범죄건수',
#        '20년6월_범죄건수', '21년6월_범죄건수', '22년6월_범죄건수', '20년7월_범죄건수', '21년7월_범죄건수',
#        '22년7월_범죄건수', '20년8월_범죄건수', '21년8월_범죄건수', '22년8월_범죄건수', '20년9월_범죄건수',
#        '21년9월_범죄건수', '22년9월_범죄건수', '20년10월_범죄건수', '21년10월_범죄건수', '22년10월_범죄건수',
#        '20년11월_범죄건수', '21년11월_범죄건수', '22년11월_범죄건수', '20년12월_범죄건수',
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn import linear_model

# %%
linear_regression = linear_model.LinearRegression()
linear_regression.fit(X = pd.DataFrame(df['2020_20대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_20대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_20대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2020_20대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_20대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_20대_여자']), y = df['총범죄건수']))
# Out:
# 절편 8796.646876824838
# 계수 [0.26706493]
# 점수 0.15851787711532572
# -----------------------------
# 절편 8177.585191568078
# 계수 [0.27912451]
# 점수 0.2169745933886562

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2020_20대_남자'], df['총범죄건수'], color='b')
plt.title('2020년 20대 남자')

plt.subplot(122)
plt.scatter(df['2020_20대_여자'], df['총범죄건수'], color='r')
plt.title('2020년 20대 여자')

plt. savefig("2020년 20대 1인가구_남여 상관관계.png")

# %%
linear_regression.fit(X = pd.DataFrame(df['2020_30대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_30대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_30대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2020_30대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_30대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_30대_여자']), y = df['총범죄건수']))
# Out:
# 절편 6427.541987903082
# 계수 [0.58531863]
# 점수 0.5180231398633777
# -----------------------------
# 절편 5838.378373266893
# 계수 [0.84405694]
# 점수 0.6537475511936296

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2020_30대_남자'], df['총범죄건수'], color='b')
plt.title('2020년 30대 남자')

plt.subplot(122)
plt.scatter(df['2020_30대_여자'], df['총범죄건수'], color='r')
plt.title('2020년 30대 여자')

plt. savefig("2020년 30대 1인가구_남여 상관관계.png")

# %%
linear_regression.fit(X = pd.DataFrame(df['2020_40대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_40대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_40대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2020_40대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_40대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_40대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2020_40대_남자'], df['총범죄건수'], color='b')
plt.title('2020년 40대 남자')

plt.subplot(122)
plt.scatter(df['2020_40대_여자'], df['총범죄건수'], color='r')
plt.title('2020년 40대 여자')

plt. savefig("2020년 40대 1인가구_남여 상관관계.png")
# Out:
# 절편 4077.4409413715302
# 계수 [1.54519953]
# 점수 0.558080055283144
# -----------------------------
# 절편 3779.68775036004
# 계수 [2.13897234]
# 점수 0.6124325744005871

# %%
linear_regression.fit(X = pd.DataFrame(df['2020_50대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_50대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_50대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2020_50대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2020_50대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2020_50대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2020_50대_남자'], df['총범죄건수'], color='b')
plt.title('2020년 50대 남자')

plt.subplot(122)
plt.scatter(df['2020_50대_여자'], df['총범죄건수'], color='r')
plt.title('2020년 50대 여자')

plt. savefig("2020년 50대 1인가구_남여 상관관계.png")
# Out:
# 절편 6055.115595787683
# 계수 [1.16081886]
# 점수 0.1896135189118382
# -----------------------------
# 절편 5254.977886807625
# 계수 [1.79843597]
# 점수 0.23400828985396338

# %%
linear_regression.fit(X = pd.DataFrame(df['2021_20대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_20대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_20대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2021_20대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_20대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_20대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2021_20대_남자'], df['총범죄건수'], color='b')
plt.title('2021년 20대 남자')

plt.subplot(122)
plt.scatter(df['2021_20대_여자'], df['총범죄건수'], color='r')
plt.title('2021년 20대 여자')

plt. savefig("2021년 20대 1인가구_남여 상관관계.png")
# Out:
# 절편 8800.218089690627
# 계수 [0.24887697]
# 점수 0.15047153926348988
# -----------------------------
# 절편 8111.371633499279
# 계수 [0.26609446]
# 점수 0.2144447341050031

# %%
linear_regression.fit(X = pd.DataFrame(df['2021_30대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_30대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_30대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2021_30대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_30대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_30대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2021_30대_남자'], df['총범죄건수'], color='b')
plt.title('2021년 30대 남자')

plt.subplot(122)
plt.scatter(df['2021_30대_여자'], df['총범죄건수'], color='r')
plt.title('2021년 30대 여자')

plt. savefig("2021년 30대 1인가구_남여 상관관계.png")
# Out:
# 절편 6376.287376767103
# 계수 [0.54732935]
# 점수 0.5011401844221655
# -----------------------------
# 절편 5757.860939096266
# 계수 [0.78827774]
# 점수 0.6278647690020699

# %%
linear_regression.fit(X = pd.DataFrame(df['2021_40대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_40대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_40대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2021_40대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_40대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_40대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2021_40대_남자'], df['총범죄건수'], color='b')
plt.title('2021년 40대 남자')

plt.subplot(122)
plt.scatter(df['2021_40대_여자'], df['총범죄건수'], color='r')
plt.title('2021년 40대 여자')

plt. savefig("2021년 40대 1인가구_남여 상관관계.png")
# Out:
# 절편 4245.140663103136
# 계수 [1.45155726]
# 점수 0.5616918178432381
# -----------------------------
# 절편 3974.2495029406646
# 계수 [1.98927126]
# 점수 0.6110813338194128

# %%
linear_regression.fit(X = pd.DataFrame(df['2021_50대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_50대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_50대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2021_50대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2021_50대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2021_50대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2021_50대_남자'], df['총범죄건수'], color='b')
plt.title('2021년 50대 남자')

plt.subplot(122)
plt.scatter(df['2021_50대_여자'], df['총범죄건수'], color='r')
plt.title('2021년 50대 여자')

plt. savefig("2021년 50대 1인가구_남여 상관관계.png")
# Out:
# 절편 5492.799296002958
# 계수 [1.24174954]
# 점수 0.2395870496629856
# -----------------------------
# 절편 4820.992534105534
# 계수 [1.86785092]
# 점수 0.26645446978465626

# %%
linear_regression.fit(X = pd.DataFrame(df['2022_20대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_20대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_20대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2022_20대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_20대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_20대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2022_20대_남자'], df['총범죄건수'], color='b')
plt.title('2022년 20대 남자')

plt.subplot(122)
plt.scatter(df['2022_20대_여자'], df['총범죄건수'], color='r')
plt.title('2022년 20대 여자')

plt. savefig("2022년 20대 1인가구_남여 상관관계.png")
# Out:
# 절편 8859.00611661686
# 계수 [0.23198459]
# 점수 0.15026136470763496
# -----------------------------
# 절편 8141.703492446077
# 계수 [0.25188613]
# 점수 0.2151078175480391

# %%
linear_regression.fit(X = pd.DataFrame(df['2022_30대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_30대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_30대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2022_30대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_30대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_30대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2022_30대_남자'], df['총범죄건수'], color='b')
plt.title('2022년 30대 남자')

plt.subplot(122)
plt.scatter(df['2022_30대_여자'], df['총범죄건수'], color='r')
plt.title('2022년 30대 여자')

plt. savefig("2022년 30대 1인가구_남여 상관관계.png")
# Out:
# 절편 6525.2945872064265
# 계수 [0.49775881]
# 점수 0.48165005124117977
# -----------------------------
# 절편 5835.8802462510575
# 계수 [0.72400071]
# 점수 0.6004278050786432

# %%
linear_regression.fit(X = pd.DataFrame(df['2022_40대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_40대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_40대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2022_40대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_40대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_40대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2022_40대_남자'], df['총범죄건수'], color='b')
plt.title('2022년 40대 남자')

plt.subplot(122)
plt.scatter(df['2022_40대_여자'], df['총범죄건수'], color='r')
plt.title('2022년 40대 여자')

plt. savefig("2022년 40대 1인가구_남여 상관관계.png")
# Out:
# 절편 4367.249495662218
# 계수 [1.40117646]
# 점수 0.5659381798209181
# -----------------------------
# 절편 4033.81837684723
# 계수 [1.8986453]
# 점수 0.6192212876014163

# %%
linear_regression.fit(X = pd.DataFrame(df['2022_50대_남자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_50대_남자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_50대_남자']), y = df['총범죄건수']))
print('-----------------------------')
linear_regression.fit(X = pd.DataFrame(df['2022_50대_여자']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['2022_50대_여자']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['2022_50대_여자']), y = df['총범죄건수']))

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(15, 5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9, wspace=0.2, hspace=0.4)

plt.subplot(121)
plt.scatter(df['2022_50대_남자'], df['총범죄건수'], color='b')
plt.title('2022년 50대 남자')

plt.subplot(122)
plt.scatter(df['2022_50대_여자'], df['총범죄건수'], color='r')
plt.title('2022년 50대 여자')

plt. savefig("2022년 50대 1인가구_남여 상관관계.png")
# Out:
# 절편 5507.647325607774
# 계수 [1.21490401]
# 점수 0.2442282440905661
# -----------------------------
# 절편 4711.909291582938
# 계수 [1.84497678]
# 점수 0.27205902859545616
