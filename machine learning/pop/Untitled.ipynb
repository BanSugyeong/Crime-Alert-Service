# %%
import pandas as pd

# %%
df = pd.read_csv('1._20231005155034.csv', encoding='utf-8')
df
# Out:
#     자치구별(2)  성별(1)    2020  2020.1  2020.2  2020.3  2020.4  2020.5  2020.6  \
# 0   자치구별(2)  성별(1)  20~24세  25~29세  30~34세  35~39세  40~44세  45~49세  50~54세
# 1       강남구     여자    2483    6592    6302    4984    3287    2517    1713
# 2       강남구     남자    1107    4629    5732    4449    3086    2664    1987
# 3       강동구     여자    1360    4002    2712    2043    1635    1537    1408
# 4       강동구     남자     611    2988    3412    2614    2111    2246    2184
# 5       강북구     여자    2257    2555    1532    1206    1078    1342    1420
# 6       강북구     남자     780    2339    2163    1810    1710    1934    2059
# 7       강서구     여자    3291    9363    5985    3727    2579    2229    2047
# 8       강서구     남자    1151    6280    7192    5171    3340    3104    2728
# 9       관악구     여자    9914   17461    8444    4246    2567    2071    1895
# 10      관악구     남자    5979   18870   13358    7096    4496    4202    3450
# ...

# %%
df = df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#     자치구별(2)  성별(1)    2020   2020.1   2020.2  2020.3  2020.4  2020.5  2020.6  \
# 0       NaN    NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1       NaN    NaN  2483.0   6592.0   6302.0  4984.0  3287.0  2517.0  1713.0
# 2       NaN    NaN  1107.0   4629.0   5732.0  4449.0  3086.0  2664.0  1987.0
# 3       NaN    NaN  1360.0   4002.0   2712.0  2043.0  1635.0  1537.0  1408.0
# 4       NaN    NaN   611.0   2988.0   3412.0  2614.0  2111.0  2246.0  2184.0
# 5       NaN    NaN  2257.0   2555.0   1532.0  1206.0  1078.0  1342.0  1420.0
# 6       NaN    NaN   780.0   2339.0   2163.0  1810.0  1710.0  1934.0  2059.0
# 7       NaN    NaN  3291.0   9363.0   5985.0  3727.0  2579.0  2229.0  2047.0
# 8       NaN    NaN  1151.0   6280.0   7192.0  5171.0  3340.0  3104.0  2728.0
# 9       NaN    NaN  9914.0  17461.0   8444.0  4246.0  2567.0  2071.0  1895.0
# 10      NaN    NaN  5979.0  18870.0  13358.0  7096.0  4496.0  4202.0  3450.0
# ...

# %%
df.columns
# Out:
# Index(['자치구별(2)', '성별(1)', '2020', '2020.1', '2020.2', '2020.3', '2020.4',
#        '2020.5', '2020.6', '2020.7', '2021', '2021.1', '2021.2', '2021.3',
#        '2021.4', '2021.5', '2021.6', '2021.7', '2022', '2022.1', '2022.2',
#        '2022.3', '2022.4', '2022.5', '2022.6', '2022.7'],
#       dtype='object')

# %%
df['2020_20대'] = df["2020"] + df['2020.1']
df['2020_30대'] = df["2020.2"] + df['2020.3']
df['2020_40대'] = df["2020.4"] + df['2020.5']
df['2020_50대'] = df["2020.6"] + df['2020.7']

df['2021_20대'] = df["2021"] + df['2021.1']
df['2021_30대'] = df["2021.2"] + df['2021.3']
df['2021_40대'] = df["2021.4"] + df['2021.5']
df['2021_50대'] = df["2021.6"] + df['2021.7']

df['2022_20대'] = df["2022"] + df['2022.1']
df['2022_30대'] = df["2022.2"] + df['2022.3']
df['2022_40대'] = df["2022.4"] + df['2022.5']
df['2022_50대'] = df["2022.6"] + df['2022.7']

# %%
df
# Out:
#     자치구별(2)  성별(1)    2020   2020.1   2020.2  2020.3  2020.4  2020.5  2020.6  \
# 0       NaN    NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1       NaN    NaN  2483.0   6592.0   6302.0  4984.0  3287.0  2517.0  1713.0
# 2       NaN    NaN  1107.0   4629.0   5732.0  4449.0  3086.0  2664.0  1987.0
# 3       NaN    NaN  1360.0   4002.0   2712.0  2043.0  1635.0  1537.0  1408.0
# 4       NaN    NaN   611.0   2988.0   3412.0  2614.0  2111.0  2246.0  2184.0
# 5       NaN    NaN  2257.0   2555.0   1532.0  1206.0  1078.0  1342.0  1420.0
# 6       NaN    NaN   780.0   2339.0   2163.0  1810.0  1710.0  1934.0  2059.0
# 7       NaN    NaN  3291.0   9363.0   5985.0  3727.0  2579.0  2229.0  2047.0
# 8       NaN    NaN  1151.0   6280.0   7192.0  5171.0  3340.0  3104.0  2728.0
# 9       NaN    NaN  9914.0  17461.0   8444.0  4246.0  2567.0  2071.0  1895.0
# 10      NaN    NaN  5979.0  18870.0  13358.0  7096.0  4496.0  4202.0  3450.0
# ...

# %%
df.to_csv('1인가구.csv', encoding='cp949', index=False)
df

# %%
# Out:
#     자치구별(2)  성별(1)    2020   2020.1   2020.2  2020.3  2020.4  2020.5  2020.6  \
# 0       NaN    NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1       NaN    NaN  2483.0   6592.0   6302.0  4984.0  3287.0  2517.0  1713.0
# 2       NaN    NaN  1107.0   4629.0   5732.0  4449.0  3086.0  2664.0  1987.0
# 3       NaN    NaN  1360.0   4002.0   2712.0  2043.0  1635.0  1537.0  1408.0
# 4       NaN    NaN   611.0   2988.0   3412.0  2614.0  2111.0  2246.0  2184.0
# 5       NaN    NaN  2257.0   2555.0   1532.0  1206.0  1078.0  1342.0  1420.0
# 6       NaN    NaN   780.0   2339.0   2163.0  1810.0  1710.0  1934.0  2059.0
# 7       NaN    NaN  3291.0   9363.0   5985.0  3727.0  2579.0  2229.0  2047.0
# 8       NaN    NaN  1151.0   6280.0   7192.0  5171.0  3340.0  3104.0  2728.0
# 9       NaN    NaN  9914.0  17461.0   8444.0  4246.0  2567.0  2071.0  1895.0
# 10      NaN    NaN  5979.0  18870.0  13358.0  7096.0  4496.0  4202.0  3450.0
# ...

# %%
df.to_csv('1인가구.csv', encoding='cp949', index=False)
df
# Out:
#     자치구별(2)  성별(1)    2020   2020.1   2020.2  2020.3  2020.4  2020.5  2020.6  \
# 0       NaN    NaN     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1       NaN    NaN  2483.0   6592.0   6302.0  4984.0  3287.0  2517.0  1713.0
# 2       NaN    NaN  1107.0   4629.0   5732.0  4449.0  3086.0  2664.0  1987.0
# 3       NaN    NaN  1360.0   4002.0   2712.0  2043.0  1635.0  1537.0  1408.0
# 4       NaN    NaN   611.0   2988.0   3412.0  2614.0  2111.0  2246.0  2184.0
# 5       NaN    NaN  2257.0   2555.0   1532.0  1206.0  1078.0  1342.0  1420.0
# 6       NaN    NaN   780.0   2339.0   2163.0  1810.0  1710.0  1934.0  2059.0
# 7       NaN    NaN  3291.0   9363.0   5985.0  3727.0  2579.0  2229.0  2047.0
# 8       NaN    NaN  1151.0   6280.0   7192.0  5171.0  3340.0  3104.0  2728.0
# 9       NaN    NaN  9914.0  17461.0   8444.0  4246.0  2567.0  2071.0  1895.0
# 10      NaN    NaN  5979.0  18870.0  13358.0  7096.0  4496.0  4202.0  3450.0
# ...
