# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\jonat\anaconda3\lib\site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (1.2.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (3.7.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (1.5.3)
# Requirement already satisfied: holidays>=0.25 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (0.37)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in c:\users\jonat\anaconda3\lib\site-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in c:\users\jonat\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in c:\users\jonat\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jonat\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jonat\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.7)
# Requirement already satisfied: colorama in c:\users\jonat\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\jonat\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

import datetime
import warnings

warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('crime_rape.csv', encoding='cp949', index_col=0)
df.head()
# Out:
#      20년1월_강간/강제추행  20년2월_강간/강제추행  20년3월_강간/강제추행  20년4월_강간/강제추행  \
# 자치구
# 강남구             65             46             64             53
# 강동구             12              9              7             13
# 강북구             13             16              9             10
# 강서구             33             17             23             17
# 관악구             37             26             27             22
#
#      20년5월_강간/강제추행  20년6월_강간/강제추행  20년7월_강간/강제추행  20년8월_강간/강제추행  \
# 자치구
# 강남구             48             58             57             60
# 강동구             12             20             26             21
# 강북구             16             18             14             20
# 강서구             16             21             22             35
# 관악구             20             34             38             33
#
#      20년9월_강간/강제추행  20년10월_강간/강제추행  ...  22년3월_강간/강제추행  22년4월_강간/강제추행  \
# 자치구                                 ...
# 강남구             19              45  ...             38             47
# 강동구             10              23  ...             12              9
# 강북구             16               9  ...              9             22
# 강서구             11              21  ...             20             21
# 관악구             18              43  ...             23             27
#
#      22년5월_강간/강제추행  22년6월_강간/강제추행  22년7월_강간/강제추행  22년8월_강간/강제추행  \
# 자치구
# 강남구             61             49             65             72
# 강동구             12             16             16             16
# 강북구             15             17             17             20
# 강서구             22             18             24             29
# 관악구             17             25             33             42
#
#      22년9월_강간/강제추행  22년10월_강간/강제추행  22년11월_강간/강제추행  22년12월_강간/강제추행
# 자치구
# 강남구             65              61              64              56
# 강동구              9              12              15              15
# 강북구             17              10              16              18
# 강서구             17              30              24              25
# 관악구             26              40              27              24
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['20년1월_강간/강제추행', '20년2월_강간/강제추행', '20년3월_강간/강제추행', '20년4월_강간/강제추행',
#        '20년5월_강간/강제추행', '20년6월_강간/강제추행', '20년7월_강간/강제추행', '20년8월_강간/강제추행',
#        '20년9월_강간/강제추행', '20년10월_강간/강제추행', '20년11월_강간/강제추행', '20년12월_강간/강제추행',
#        '21년1월_강간/강제추행', '21년2월_강간/강제추행', '21년3월_강간/강제추행', '21년4월_강간/강제추행',
#        '21년5월_강간/강제추행', '21년6월_강간/강제추행', '21년7월_강간/강제추행', '21년8월_강간/강제추행',
#        '21년9월_강간/강제추행', '21년10월_강간/강제추행', '21년11월_강간/강제추행', '21년12월_강간/강제추행',
#        '22년1월_강간/강제추행', '22년2월_강간/강제추행', '22년3월_강간/강제추행', '22년4월_강간/강제추행',
#        '22년5월_강간/강제추행', '22년6월_강간/강제추행', '22년7월_강간/강제추행', '22년8월_강간/강제추행',
#        '22년9월_강간/강제추행', '22년10월_강간/강제추행', '22년11월_강간/강제추행', '22년12월_강간/강제추행'],
#       dtype='object')

# %%
pattern = ['20년', '21년', '22년']
months = [f'{month}월' for month in range(1, 13)]
sorted_columns = [f'{year}{month}_강간/강제추행' for year in pattern for month in months]

# 패턴에 따라 칼럼 이름 정렬
df = df.reindex(columns=sorted_columns)

# %%
df.head()
# Out:
#      20년1월_강간/강제추행  20년2월_강간/강제추행  20년3월_강간/강제추행  20년4월_강간/강제추행  \
# 자치구
# 강남구             65             46             64             53
# 강동구             12              9              7             13
# 강북구             13             16              9             10
# 강서구             33             17             23             17
# 관악구             37             26             27             22
#
#      20년5월_강간/강제추행  20년6월_강간/강제추행  20년7월_강간/강제추행  20년8월_강간/강제추행  \
# 자치구
# 강남구             48             58             57             60
# 강동구             12             20             26             21
# 강북구             16             18             14             20
# 강서구             16             21             22             35
# 관악구             20             34             38             33
#
#      20년9월_강간/강제추행  20년10월_강간/강제추행  ...  22년3월_강간/강제추행  22년4월_강간/강제추행  \
# 자치구                                 ...
# 강남구             19              45  ...             38             47
# 강동구             10              23  ...             12              9
# 강북구             16               9  ...              9             22
# 강서구             11              21  ...             20             21
# 관악구             18              43  ...             23             27
#
#      22년5월_강간/강제추행  22년6월_강간/강제추행  22년7월_강간/강제추행  22년8월_강간/강제추행  \
# 자치구
# 강남구             61             49             65             72
# 강동구             12             16             16             16
# 강북구             15             17             17             20
# 강서구             22             18             24             29
# 관악구             17             25             33             42
#
#      22년9월_강간/강제추행  22년10월_강간/강제추행  22년11월_강간/강제추행  22년12월_강간/강제추행
# 자치구
# 강남구             65              61              64              56
# 강동구              9              12              15              15
# 강북구             17              10              16              18
# 강서구             17              30              24              25
# 관악구             26              40              27              24
#
# [5 rows x 36 columns]

# %%
data = df.T
data.to_csv('시계열분석_전처리_성폭력.csv', encoding='cp949')
data.head()
# Out:
# 자치구            강남구  강동구  강북구  강서구  관악구  광진구  구로구  금천구  노원구  도봉구  ...  성동구  \
# 20년1월_강간/강제추행   65   12   13   33   37   20   18    8    7    8  ...   11
# 20년2월_강간/강제추행   46    9   16   17   26   21    5   10   11    8  ...   11
# 20년3월_강간/강제추행   64    7    9   23   27   19   12   10    6    9  ...    7
# 20년4월_강간/강제추행   53   13   10   17   22   23   11   10   16    6  ...    9
# 20년5월_강간/강제추행   48   12   16   16   20   17   11   11   13    4  ...    4
#
# 자치구            성북구  송파구  양천구  영등포구  용산구  은평구  종로구  중구  중랑구
# 20년1월_강간/강제추행    7   23   11    33   23   15    8  22   14
# 20년2월_강간/강제추행   10   16    8    23   23    8   12  16   15
# 20년3월_강간/강제추행   11   18    9    22   32   10   18  11   14
# 20년4월_강간/강제추행   15   27   16    20   28   13    9  16    8
# 20년5월_강간/강제추행    7   24    6    32   14   15   19  14   12
#
# [5 rows x 25 columns]

# %%
df = pd.read_csv('시계열분석_전처리_성폭력.csv', encoding='cp949')
df.head()
# Out:
#             Date  강남구  강동구  강북구  강서구  관악구  광진구  구로구  금천구  노원구  ...  성동구  성북구  \
# 0  20년1월_강간/강제추행   65   12   13   33   37   20   18    8    7  ...   11    7
# 1  20년2월_강간/강제추행   46    9   16   17   26   21    5   10   11  ...   11   10
# 2  20년3월_강간/강제추행   64    7    9   23   27   19   12   10    6  ...    7   11
# 3  20년4월_강간/강제추행   53   13   10   17   22   23   11   10   16  ...    9   15
# 4  20년5월_강간/강제추행   48   12   16   16   20   17   11   11   13  ...    4    7
#
#    송파구  양천구  영등포구  용산구  은평구  종로구  중구  중랑구
# 0   23   11    33   23   15    8  22   14
# 1   16    8    23   23    8   12  16   15
# 2   18    9    22   32   10   18  11   14
# 3   27   16    20   28   13    9  16    8
# 4   24    6    32   14   15   19  14   12
#
# [5 rows x 26 columns]

# %%
# '범죄건수' 문자열 삭제
df['Date'] = df['Date'].str.replace('_강간/강제추행', '')

df['Date'] = df['Date'].str.replace(r'(\d+)년(\d+)월', r'20\1\2', regex=True)

df['Date'] = pd.to_datetime(df['Date'], format='%Y%m').dt.strftime('%Y%m')

df.head()
# Out:
#      Date  강남구  강동구  강북구  강서구  관악구  광진구  구로구  금천구  노원구  ...  성동구  성북구  송파구  \
# 0  202001   65   12   13   33   37   20   18    8    7  ...   11    7   23
# 1  202002   46    9   16   17   26   21    5   10   11  ...   11   10   16
# 2  202003   64    7    9   23   27   19   12   10    6  ...    7   11   18
# 3  202004   53   13   10   17   22   23   11   10   16  ...    9   15   27
# 4  202005   48   12   16   16   20   17   11   11   13  ...    4    7   24
#
#    양천구  영등포구  용산구  은평구  종로구  중구  중랑구
# 0   11    33   23   15    8  22   14
# 1    8    23   23    8   12  16   15
# 2    9    22   32   10   18  11   14
# 3   16    20   28   13    9  16    8
# 4    6    32   14   15   19  14   12
#
# [5 rows x 26 columns]

# %%
gu_name = ['중랑구', 'Date']

last_3year = list()
for i in range(2023, 2027):
    for j in range(1, 13):
        last_3year.append(['%04d-%02d' % (i,j)])
        
        
last_3year = pd.DataFrame(last_3year, columns = ['ds'])
last_3year['ds']= pd.to_datetime(last_3year['ds'])

for i in range(len(df['Date'])):
    date_time_str = df['Date'][i]
    
    date = datetime.datetime.strptime(str(date_time_str), '%Y%m')  #datetime.datetime.strptime(date, "%Y-%m-%d")
    
    df['Date'][i] = date

jungrang_predict = pd.DataFrame()

for i,name in enumerate(gu_name):
    data = pd.DataFrame()
    data = df[[name,'Date']]
    data.columns = ['y','ds']
    data['ds'] = pd.to_datetime(data['ds'])

    model = Prophet().fit(data)
    print(i,"model_fit")
    forecast = model.predict(last_3year)
    print(i,"model_predict")
    jungrang_predict = pd.concat([jungrang_predict, forecast['yhat']], ignore_index = True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 15
#      12 for i in range(len(df['Date'])):
#      13     date_time_str = df['Date'][i]
# ---> 15     date = datetime.datetime.strptime(str(date_time_str), '%Y%m')  #datetime.datetime.strptime(date, "%Y-%m-%d")
#      17     df['Date'][i] = date
#      19 jungrang_predict = pd.DataFrame()
#
# File ~\anaconda3\Lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\anaconda3\Lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2020-01-01 00:00:00' does not match format '%Y%m'

# %%
jungrang_predict = pd.concat([jungrang_predict, forecast['ds']], ignore_index = True, axis=1)

jungrang_predict.columns = ['중랑구', 'Date']

jungrang_predict.to_csv('jungrang_rape_predict.csv', encoding='cp949',index = False)
