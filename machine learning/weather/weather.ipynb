# %%
import pandas as pd

rain = pd.read_csv("강수량분석자료_20202022.csv", encoding='cp949', )
temp = pd.read_csv('기온분석자료_20202022.csv', encoding='cp949')
humidity = pd.read_csv('습도분석자료_20202022.csv', encoding='cp949')
wind = pd.read_csv('풍속분석자료_20202022.csv', encoding='cp949')

# %%
# 데이터에서 필요한 칼럼만 가져오기
new_columns = ['일시', '강수량(mm)']
rain = rain[new_columns]

temp = temp['평균기온(℃)']
wind = wind['평균풍속(m/s)']
humidity = humidity['평균습도(%rh)']


# 행 기준으로 데이터프레임 합치기
df = pd.concat([rain, temp, wind, humidity], axis=1)
df
# Out:
#         일시  강수량(mm)  평균기온(℃)  평균풍속(m/s)  평균습도(%rh)
# 0   Jan-20     60.5      1.6        2.1       56.0
# 1   Feb-20     53.1      2.5        2.3       58.0
# 2   Mar-20     16.3      7.7        2.5       46.0
# 3   Apr-20     16.9     11.1        3.0       50.0
# 4   May-20    112.4     18.0        2.4       67.0
# 5   Jun-20    139.6     23.9        2.3       68.0
# 6   Jul-20    270.4     24.1        2.4       77.0
# 7   Aug-20    675.7     26.5        2.3       85.0
# 8   Sep-20    181.5     21.4        2.5       71.0
# 9   Oct-20      0.0     14.3        2.1       61.0
# 10  Nov-20    120.1      8.0        2.2       64.0
# 11  Dec-20      4.6     -0.3        2.2       58.0
# 12  Jan-21     18.9     -2.4        2.5       58.0
# 13  Feb-21      7.1      2.7        2.6       56.0
# 14  Mar-21    110.9      9.0        2.4       63.0
# 15  Apr-21    124.1     14.2        2.6       54.0
# 16  May-21    183.1     17.1        2.4       68.0
# 17  Jun-21    104.6     22.8        2.2       73.0
# 18  Jul-21    168.3     28.1        2.0       71.0
# 19  Aug-21    211.2     25.9        2.1       74.0
# 20  Sep-21    131.0     22.6        2.3       71.0
# 21  Oct-21     57.0     15.6        2.1       70.0
# 22  Nov-21     62.4      8.2        2.1       68.0
# 23  Dec-21      7.9      0.6        2.3       62.0
# 24  Jan-22      5.5     -2.2        2.2       55.0
# 25  Feb-22      4.7     -1.1        2.6       55.0
# 26  Mar-22    102.6      7.7        2.5       62.0
# 27  Apr-22     20.4     14.8        2.7       55.0
# 28  May-22      7.5     19.1        2.6       55.0
# 29  Jun-22    393.8     23.3        2.5       73.0
# 30  Jul-22    252.3     27.3        2.1       77.0
# 31  Aug-22    564.8     25.7        2.3       80.0
# 32  Sep-22    201.5     22.4        2.4       68.0
# 33  Oct-22    124.1     14.6        2.2       69.0
# 34  Nov-22     84.5     10.0        2.1       65.0
# 35  Dec-22     13.6     -2.8        2.3       59.0
# 36     NaN      NaN      NaN        NaN        NaN
# 37     NaN      NaN      NaN        NaN        NaN
# 38     NaN      NaN      NaN        NaN        NaN
# 39     NaN      NaN      NaN        NaN        NaN
# 40     NaN      NaN      NaN        NaN        NaN
# 41     NaN      NaN      NaN        NaN        NaN
# 42     NaN      NaN      NaN        NaN        NaN
# 43     NaN      NaN      NaN        NaN        NaN

# %%
# NaN 값 삭제
df = df.dropna()
# 데이터 저장
df.to_csv('날씨데이터총합_20202022.csv', encoding='cp949', index=False)

# %%
data = pd.read_csv('날씨데이터총합_20202022.csv', encoding='cp949', index_col=0)
data
# Out:
#         강수량(mm)  평균기온(℃)  평균풍속(m/s)  평균습도(%rh)
# 일시
# Jan-20     60.5      1.6        2.1       56.0
# Feb-20     53.1      2.5        2.3       58.0
# Mar-20     16.3      7.7        2.5       46.0
# Apr-20     16.9     11.1        3.0       50.0
# May-20    112.4     18.0        2.4       67.0
# Jun-20    139.6     23.9        2.3       68.0
# Jul-20    270.4     24.1        2.4       77.0
# Aug-20    675.7     26.5        2.3       85.0
# Sep-20    181.5     21.4        2.5       71.0
# Oct-20      0.0     14.3        2.1       61.0
# Nov-20    120.1      8.0        2.2       64.0
# Dec-20      4.6     -0.3        2.2       58.0
# Jan-21     18.9     -2.4        2.5       58.0
# Feb-21      7.1      2.7        2.6       56.0
# Mar-21    110.9      9.0        2.4       63.0
# Apr-21    124.1     14.2        2.6       54.0
# May-21    183.1     17.1        2.4       68.0
# Jun-21    104.6     22.8        2.2       73.0
# Jul-21    168.3     28.1        2.0       71.0
# Aug-21    211.2     25.9        2.1       74.0
# Sep-21    131.0     22.6        2.3       71.0
# Oct-21     57.0     15.6        2.1       70.0
# Nov-21     62.4      8.2        2.1       68.0
# Dec-21      7.9      0.6        2.3       62.0
# Jan-22      5.5     -2.2        2.2       55.0
# Feb-22      4.7     -1.1        2.6       55.0
# Mar-22    102.6      7.7        2.5       62.0
# Apr-22     20.4     14.8        2.7       55.0
# May-22      7.5     19.1        2.6       55.0
# Jun-22    393.8     23.3        2.5       73.0
# Jul-22    252.3     27.3        2.1       77.0
# Aug-22    564.8     25.7        2.3       80.0
# Sep-22    201.5     22.4        2.4       68.0
# Oct-22    124.1     14.6        2.2       69.0
# Nov-22     84.5     10.0        2.1       65.0
# Dec-22     13.6     -2.8        2.3       59.0

# %%
# 인덱스 rename
data = data.rename(index={'Jan-20':202001, 'Feb-20':202002, 'Mar-20':202003, 'Apr-20':202004, 'May-20':202005, 'Jun-20':202006, 'Jul-20':202007, 'Aug-20':202008, 'Sep-20':202009, 'Oct-20':202010, 'Nov-20':202011, 'Dec-20':202012, 
                          'Jan-21':202101, 'Feb-21':202102, 'Mar-21':202103, 'Apr-21':202104, 'May-21':202105, 'Jun-21':202106, 'Jul-21':202107, 'Aug-21':202108, 'Sep-21':202109, 'Oct-21':202110, 'Nov-21':202111, 'Dec-21':202112, 
                          'Jan-22':202201, 'Feb-22':202202, 'Mar-22':202203, 'Apr-22':202204, 'May-22':202205, 'Jun-22':202206, 'Jul-22':202207, 'Aug-22':202208, 'Sep-22':202209, 'Oct-22':202210, 'Nov-22':202211, 'Dec-22':202212})
data
# Out:
#         강수량(mm)  평균기온(℃)  평균풍속(m/s)  평균습도(%rh)
# 일시
# 202001     60.5      1.6        2.1       56.0
# 202002     53.1      2.5        2.3       58.0
# 202003     16.3      7.7        2.5       46.0
# 202004     16.9     11.1        3.0       50.0
# 202005    112.4     18.0        2.4       67.0
# 202006    139.6     23.9        2.3       68.0
# 202007    270.4     24.1        2.4       77.0
# 202008    675.7     26.5        2.3       85.0
# 202009    181.5     21.4        2.5       71.0
# 202010      0.0     14.3        2.1       61.0
# 202011    120.1      8.0        2.2       64.0
# 202012      4.6     -0.3        2.2       58.0
# 202101     18.9     -2.4        2.5       58.0
# 202102      7.1      2.7        2.6       56.0
# 202103    110.9      9.0        2.4       63.0
# 202104    124.1     14.2        2.6       54.0
# 202105    183.1     17.1        2.4       68.0
# 202106    104.6     22.8        2.2       73.0
# 202107    168.3     28.1        2.0       71.0
# 202108    211.2     25.9        2.1       74.0
# 202109    131.0     22.6        2.3       71.0
# 202110     57.0     15.6        2.1       70.0
# 202111     62.4      8.2        2.1       68.0
# 202112      7.9      0.6        2.3       62.0
# 202201      5.5     -2.2        2.2       55.0
# 202202      4.7     -1.1        2.6       55.0
# 202203    102.6      7.7        2.5       62.0
# 202204     20.4     14.8        2.7       55.0
# 202205      7.5     19.1        2.6       55.0
# 202206    393.8     23.3        2.5       73.0
# 202207    252.3     27.3        2.1       77.0
# 202208    564.8     25.7        2.3       80.0
# 202209    201.5     22.4        2.4       68.0
# 202210    124.1     14.6        2.2       69.0
# 202211     84.5     10.0        2.1       65.0
# 202212     13.6     -2.8        2.3       59.0

# %%
data.to_csv('날씨데이터총합_20202022.csv', encoding='cp949')
