# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('년도별 범죄율 데이터만.csv', encoding='cp949')
df
# Out:
#      자치구   20년_범죄율   21년_범죄율   22년_범죄율  총범죄건수
# 0    강남구  0.349157  0.305513  0.345330  20117
# 1    강동구  0.329812  0.323268  0.346920  10697
# 2    강북구  0.351321  0.290787  0.357892   7913
# 3    강서구  0.327070  0.306313  0.366617  12719
# 4    관악구  0.432286  0.270613  0.297101  16422
# 5    광진구  0.336368  0.305492  0.358140  10105
# 6    구로구  0.358802  0.304401  0.336797  11452
# 7    금천구  0.356345  0.312973  0.330681   7793
# 8    노원구  0.365501  0.334538  0.299961  10238
# 9    도봉구  0.275610  0.234080  0.490310   7946
# 10  동대문구  0.396378  0.350219  0.253403   8449
# 11   동작구  0.357221  0.287415  0.355364   9154
# 12   마포구  0.354424  0.364198  0.281379   9720
# 13  서대문구  0.279937  0.257343  0.462720   8852
# 14   서초구  0.184584  0.494388  0.321028   7395
# 15   성동구  0.281229  0.231022  0.487749   9142
# 16   성북구  0.406419  0.310776  0.282805   7758
# 17   송파구  0.350105  0.310050  0.339845  15204
# 18   양천구  0.325848  0.328682  0.345470   9173
# ...

# %%
pip install sklearn
# Out:
# ...
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# ...
#     Running setup.py install for sklearn: started
#     Running setup.py install for sklearn: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
# ...

# %%
from sklearn import linear_model

# %%
df = pd.DataFrame(df)

# %%
linear_regression = linear_model.LinearRegression()
linear_regression.fit(X = pd.DataFrame(df['자치구']), y = df['총범죄건수'])
prediction = linear_regression.predict(X = pd.DataFrame(df['자치구']))
print('절편', linear_regression.intercept_)
print('계수', linear_regression.coef_)
print('점수', linear_regression.score(X = pd.DataFrame(df['자치구']), y = df['총범죄건수']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\D드라이브 바탕화면\갱\대학교\3-2\캡스톤디자인1\crime\crime_linear.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/D%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C%20%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/%EA%B0%B1/%EB%8C%80%ED%95%99%EA%B5%90/3-2/%EC%BA%A1%EC%8A%A4%ED%86%A4%EB%94%94%EC%9E%90%EC%9D%B81/crime/crime_linear.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> linear_regression = linear_model.LinearRegression()
# ----> <a href='vscode-notebook-cell:/d%3A/D%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C%20%EB%B0%94%ED%83%95%ED%99%94%EB%A9%B4/%EA%B0%B1/%EB%8C%80%ED%95%99%EA%B5%90/3-2/%EC%BA%A1%EC%8A%A4%ED%86%A4%EB%94%94%EC%9E%90%EC%9D%B81/crime/crime_linear.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> linear_regression.fit(X = pd.DataFrame(df['자치구']), y = df['총범죄건수'])
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['자치구'], df['총범죄건수'], color='r')
plt.show()
# Out:
# C:\Users\DB-26\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\DB-26\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\DB-26\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\DB-26\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
